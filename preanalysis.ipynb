# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
cd 'drive/MyDrive/Artigo_Farmacos/'
# Out:
# /content/drive/MyDrive/Artigo_Farmacos

# %%
import pandas as pd
import seaborn as sns

# %%
df_train = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')

# %%
df_train.describe().to_csv('describe-train.csv',sep=',')

# %%
df_train.describe()
# Out:
#             Energy         TPSA      ExactMW  NumLipinskiHBA  NumLipinskiHBD  \
# count  6718.000000  6718.000000  6718.000000     6718.000000     6718.000000
# mean     18.752108    61.279375   263.399096        4.091694        1.187556
# std      67.565313    54.100973   137.977541        3.409685        1.630424
# min    -475.730576     0.000000   100.009519        0.000000        0.000000
# 25%      -2.955870    26.300000   172.074656        2.000000        0.000000
# 50%      18.521114    52.160000   235.030435        4.000000        1.000000
# 75%      46.927850    80.260000   316.031359        5.000000        2.000000
# max    2489.009082   742.740000  1647.876525       44.000000       24.000000
#
#        NumRotatableBonds       NumHBD       NumHBA  NumAmideBonds  \
# count        6718.000000  6718.000000  6718.000000    6718.000000
# mean            4.080828     0.959661     3.511015       0.445222
# std             4.480436     1.297383     3.096307       0.966719
# min             0.000000     0.000000     0.000000       0.000000
# 25%             1.000000     0.000000     2.000000       0.000000
# 50%             3.000000     1.000000     3.000000       0.000000
# 75%             5.000000     2.000000     5.000000       0.000000
# max            66.000000    24.000000    40.000000      11.000000
#
#        NumHeteroAtoms  ...  NumSaturatedRings  NumAliphaticRings  \
# count     6718.000000  ...        6718.000000        6718.000000
# mean         5.023817  ...           0.297112           0.538553
# std          3.875350  ...           0.859573           1.060161
# min          0.000000  ...           0.000000           0.000000
# 25%          3.000000  ...           0.000000           0.000000
# 50%          4.000000  ...           0.000000           0.000000
# 75%          6.000000  ...           0.000000           1.000000
# max         54.000000  ...          30.000000          30.000000
#
#        NumAromaticHeterocycles  NumSaturatedHeterocycles  \
# count              6718.000000               6718.000000
# mean                  0.174010                  0.152426
# std                   0.443567                  0.633762
# min                   0.000000                  0.000000
# 25%                   0.000000                  0.000000
# 50%                   0.000000                  0.000000
# 75%                   0.000000                  0.000000
# max                   3.000000                 30.000000
#
#        NumAliphaticHeterocycles  NumAromaticCarbocycles  \
# count               6718.000000             6718.000000
# mean                   0.293540                0.914111
# std                    0.753053                1.053394
# min                    0.000000                0.000000
# 25%                    0.000000                0.000000
# 50%                    0.000000                1.000000
# 75%                    0.000000                1.000000
# max                   30.000000                9.000000
#
#        NumSaturatedCarbocycles  NumAliphaticCarbocycles  FractionCSP3  \
# count              6718.000000              6718.000000   6718.000000
# mean                  0.144686                 0.245013      0.419506
# std                   0.557991                 0.742258      0.340128
# min                   0.000000                 0.000000      0.000000
# 25%                   0.000000                 0.000000      0.125000
# 50%                   0.000000                 0.000000      0.363636
# 75%                   0.000000                 0.000000      0.714286
# max                   6.000000                 6.000000      1.000000
#
#              SlogP
# count  6718.000000
# mean      2.158088
# std       2.642262
# min     -17.406400
# 25%       0.685900
# 50%       2.028550
# 75%       3.478530
# max      25.220400
#
# [8 rows x 25 columns]

# %%
df_test.describe().to_csv('describe-test.csv',sep=',')

# %%
df_test.describe()
# Out:
#             Energy         TPSA      ExactMW  NumLipinskiHBA  NumLipinskiHBD  \
# count  1680.000000  1680.000000  1680.000000     1680.000000     1680.000000
# mean     18.446799    61.457155   266.765214        4.107738        1.160714
# std      62.075834    53.601644   138.108680        3.390901        1.541680
# min    -520.327212     0.000000   100.016044        0.000000        0.000000
# 25%      -3.596497    27.022500   175.078170        2.000000        0.000000
# 50%      19.295095    52.600000   236.136297        4.000000        1.000000
# 75%      45.215722    80.260000   322.014930        5.000000        2.000000
# max     779.349629   623.920000  1525.950959       40.000000       18.000000
#
#        NumRotatableBonds       NumHBD       NumHBA  NumAmideBonds  \
# count        1680.000000  1680.000000  1680.000000    1680.000000
# mean            4.093452     0.923810     3.548810       0.437500
# std             4.440214     1.199128     3.128763       0.937422
# min             0.000000     0.000000     0.000000       0.000000
# 25%             1.000000     0.000000     2.000000       0.000000
# 50%             3.000000     1.000000     3.000000       0.000000
# 75%             5.000000     2.000000     4.000000       0.000000
# max            47.000000    18.000000    38.000000       6.000000
#
#        NumHeteroAtoms  ...  NumSaturatedRings  NumAliphaticRings  \
# count     1680.000000  ...        1680.000000        1680.000000
# mean         5.082143  ...           0.324405           0.570238
# std          3.866493  ...           0.933845           1.126251
# min          0.000000  ...           0.000000           0.000000
# 25%          3.000000  ...           0.000000           0.000000
# 50%          4.000000  ...           0.000000           0.000000
# 75%          6.000000  ...           0.000000           1.000000
# max         48.000000  ...          22.000000          22.000000
#
#        NumAromaticHeterocycles  NumSaturatedHeterocycles  \
# count              1680.000000               1680.000000
# mean                  0.190476                  0.166071
# std                   0.461145                  0.717627
# min                   0.000000                  0.000000
# 25%                   0.000000                  0.000000
# 50%                   0.000000                  0.000000
# 75%                   0.000000                  0.000000
# max                   4.000000                 22.000000
#
#        NumAliphaticHeterocycles  NumAromaticCarbocycles  \
# count               1680.000000             1680.000000
# mean                   0.307143                0.923810
# std                    0.815833                1.036053
# min                    0.000000                0.000000
# 25%                    0.000000                0.000000
# 50%                    0.000000                1.000000
# 75%                    0.000000                1.000000
# max                   22.000000                8.000000
#
#        NumSaturatedCarbocycles  NumAliphaticCarbocycles  FractionCSP3  \
# count              1680.000000              1680.000000   1680.000000
# mean                  0.158333                 0.263095      0.411044
# std                   0.594737                 0.772407      0.337859
# min                   0.000000                 0.000000      0.000000
# 25%                   0.000000                 0.000000      0.116013
# 50%                   0.000000                 0.000000      0.333333
# 75%                   0.000000                 0.000000      0.700000
# max                   5.000000                 5.000000      1.000000
#
#              SlogP
# count  1680.000000
# mean      2.251835
# std       2.641507
# min     -13.054800
# 25%       0.733850
# 50%       2.128300
# 75%       3.587650
# max      17.911500
#
# [8 rows x 25 columns]

# %%
pd.options.display.float_format = '{:.2f}'.format
sns.heatmap(df_train[['']].corr(),annot=True,cmap='Blues')
sns.set(rc={'figure.figsize':(25,25)})

# %%
pd.options.display.float_format = '{:.2f}'.format
sns.heatmap(df_test.corr(),annot=True,cmap='Blues')
sns.set(rc={'figure.figsize':(25,25)})
